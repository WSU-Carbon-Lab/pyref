# %%
from pathlib import Path
import sys
import matplotlib.pyplot as plt

ref_path = Path().home() / "CarbonLab" / "reflutils" / "src"

sys.path.append(str(ref_path))
import reflutils as ru

# macro_folder = make_macro_folder()

# %% [markdown]
# # Data Processing

# %%
xrr_1 = ru.Refl()
xrr_2 = ru.Refl()
# Out:
# C:\Users\hduva\CarbonLab\reflutils\src\reflutils\refl_manager.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, col].iloc[:meanCutoff] = mean[col]
# C:\Users\hduva\CarbonLab\reflutils\src\reflutils\refl_manager.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, col].iloc[:meanCutoff] = mean[col]
# C:\Users\hduva\CarbonLab\reflutils\src\reflutils\refl_manager.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
fig, ax = plt.subplots(sharex=True, gridspec_kw={"hspace": 0})
xrr_1.plot(ax=ax, label="s")
xrr_2.plot(ax=ax, label="p")

xrr_1.to_csv()
xrr_2.to_csv()

# %%
def multi_en_ploting():
    scan_number = ru.FileDialog.getDirectory()
    en = [en for en in scan_number.iterdir() if en.is_dir()]
    fig, ax = plt.subplots(
        nrows=len(en),
        figsize=(20, 4 * len(en)),
        sharex=True,
        gridspec_kw={"wspace": 0, "hspace": 0},
    )
    for e in en:
        file = scan_number / e / "100.0"
        data = ru.Refl(path=file).refl
        data.plot(
            x="Theta",
            y="Refl",
            ax=ax[en.index(e)],
            label=e.name,
            logy=True,
        )


multi_en_ploting()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 22
#      12         data = ru.Refl(path=file).refl
#      13         data.plot(
#      14             x="Theta",
#      15             y="Refl",
#    (...)
#      18             logy=True,
#      19         )
# ---> 22 multi_en_ploting()
#
# Cell In[7], line 12, in multi_en_ploting()
#      10 for e in en:
#      11     file = scan_number / e / "100.0"
# ---> 12     data = ru.Refl(path=file).refl
#      13     data.plot(
#      14         x="Theta",
#      15         y="Refl",
#    (...)
#      18         logy=True,
#      19     )
#
# File ~\CarbonLab\reflutils\src\reflutils\xrr.py:110, in Refl.__init__(self, path, backend, *backArgs, **backKWArgs)
#     108 self.backendKey: Literal["single", "multi"] = backend
#     109 self.backendProcessor = BACKEND[backend](*backArgs, **backKWArgs)
# ...
