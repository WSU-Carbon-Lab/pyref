# %%
import pandas as pd

# %%
A1 = pd.DataFrame({"a": [1, 2, 3], "b": [4, 5, 6]})
B1 = pd.DataFrame({"a": [1, 2, 3], "b": [4, 5, 6]})
A2 = pd.DataFrame({"a": [1, 2], "b": [4, 5]})
B2 = pd.DataFrame({"a": [1, 2, 3], "b": [4, 5, 6]})

A = pd.concat([A1, A2], axis=1)
B = pd.concat([B1, B2], axis=1)
df = pd.concat([A, B], axis=1)
# Out:
# <Axes: >
