# %%
from xrr import Refl
from pathlib import Path
from plotly.offline import init_notebook_mode, iplot

# %%
path = Path('tests/TestData/Sorted/ZnPc_P100_E180276/282.5/190.0').resolve()

# %%
test = Refl(path=path)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 test = Refl(path=path)
#
# File c:\Users\Harlan Heilman\CarbonLab\Refl-Utils\xrr\xrr.py:75, in Refl.__init__(self, path, backendKey, *backArgs, **backKWArgs)
#      73 self.backendKey: Literal["single", "multi"] = backendKey
#      74 self.backendProcessor = BACKEND[backendKey](*backArgs, **backKWArgs)
# ---> 75 self.backendProcessor.getData(self, path)
#      76 self.backendProcessor.saveData(self)
#
# File c:\Users\Harlan Heilman\CarbonLab\Refl-Utils\xrr\xrr.py:167, in SingleRefl.getData(self, obj, mask, source, **dataKWArgs)
#     165 def getData(self, obj: Refl, mask: np.ndarray|None = None, source: Literal['fits','csv'] = 'fits', **dataKWArgs):
#     166     metadata, obj.images, obj.path = MultiReader.main(obj.path, **dataKWArgs)
# --> 167     ReflProcs.main(obj, mask, metadata, source=source)
#
# ...

# %%
test.plot()
